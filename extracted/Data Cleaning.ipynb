# %%
import pandas as pd

# %%
file = pd.read_excel("Data.xlsx")

# %%
file.columns
# Out:
# Index(['OneDrive Link', 'Name', 'Company', 'Designation', 'Department',
#        'Mail ID', 'Phone Number', 'Unnamed: 7'],
#       dtype='object')

# %%
file
# Out:
#                                           OneDrive Link  \
# 0     https://tpmguru-my.sharepoint.com/personal/ris...
# 1     https://tpmguru-my.sharepoint.com/personal/ris...
# 2     https://tpmguru-my.sharepoint.com/personal/ris...
# 3     https://tpmguru-my.sharepoint.com/personal/ris...
# 4     https://tpmguru-my.sharepoint.com/personal/ris...
# ...                                                 ...
# 1036  https://tpmguru-my.sharepoint.com/personal/ris...
# 1037  https://tpmguru-my.sharepoint.com/personal/ris...
# 1038  https://tpmguru-my.sharepoint.com/personal/ris...
# 1039  https://tpmguru-my.sharepoint.com/personal/ris...
# 1040  https://tpmguru-my.sharepoint.com/personal/ris...
#
#                                                    Name  \
# 0                                        @ Nikhil Arora
# 1                                                @ Anil
# 2                                               Patnaik
# 3                                     @ Mr. Priyank Nag
# ...

# %%
file.to_excel("Noida Leads data v2.xlsx")

# %%
file['OneDrive Link'].ffill(inplace=True)

# %%
file.shape
# Out:
# (1041, 8)

# %%
file['Name'] = file['Name'].fillna('0')

# %%
multiple_names = [x for x in names if len(x) > 20]

# %%
for names in multiple_names:
    count_words = names.split(" ")
    if len(count_words) % 2 == 0:
        print(names)
# Out:
# Ashvani Kumar Singh Chandel
# Kalpesh Sheth R Ravichandran Vinod Pandey
# Singh @ Sachin kumar Vishwakarma @ Ankush Sharma
# @ Sharad Kumar Sharma
# Kamaljit Singh Ankit Khare
# Vimal raj Puri Amlnformation Technologyabh Jyotirmay
# Dr JS Sodhi @ Ayushman Sinha
# Sanjeev Batra Pk Sharma
# Gupta @ Ranjeet Singh
# Sudeep Majumdar Deepti Gupta
# @ Asha Pathak @ Ashwani Kumar
# Mohammed Ranapurwala Sunil Kumar
# @ Krishna Prasad Acharya
# Bhawanand Choudhary •O Aman
# @ Sudhanshu J ha Manish Gupta
# Capt Ajay Kumar Gulati
# Vinay Shukla @ Lipika
# RAKESH GUPTA Suneel Singh
# @ Indranil Roy Burman
# Ravi Shankar Anubhav Jain
# Ankit Khatri Sunil Shah
# Santosh Sareen Nikhlesh Daga
# Sahil Jain Inder Thapa
# Harshal Kherde Shalabh Nigam
# Pankaj Vinayak Ravi Raman
# Sujain Abharabam Kuna/ Kumar Deepshikha Aggarwal Manas Pattnaik Avnish Sharma
# Abhimanyu Singh Sanjay Mittal
# Yogesh Rao Iqbal Kaur
# Chandan Kanodia Rajesh Khanna
# Naveen Vaila Rahul Verma
# ...
